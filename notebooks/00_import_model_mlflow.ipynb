# %% [markdown]
# # Import du modele via MLflow
#
# ---
#
# - **Projet 8 :** Confirmez vos compétences en MLOps (Partie 2/2)
# - **Auteur :** Justine Tranchant
# - **Date :** mars 2026
#
# ---
#
# ## Objectif
#
# Cette étape vise à : préparer l'import du modèle via MLflow et documenter le flux de récupération de l'artefact.

# %% [markdown]
# ## Étapes prévues
#
# - définir l'URI MLflow du modèle à récupérer ;
# - charger l'artefact depuis MLflow ;
# - sauvegarder les métadonnées locales utiles au projet.

# %%
# TODO : ajouter ici les imports et la logique d'import du modèle via MLflow.
