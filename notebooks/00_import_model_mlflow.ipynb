# %% [markdown]
# # Import du modele via MLflow
#
# ---
#
# - **Projet 8 :** Confirmez vos compétences en MLOps (Partie 2/2)
# - **Auteur :** Justine Tranchant
# - **Date :** mars 2026
#
# ---
#
# ## Objectif
#
# Cette étape vise à : importer dans le projet 8 le modèle sélectionné dans le projet 6, stocké dans MLflow, puis sauvegarder localement l’artefact utile et un fichier de métadonnées minimal.

# %% [markdown]
# ## Étapes réalisées
# - définir l’URI de tracking MLflow ;
# - définir l’URI de l’artefact du modèle à récupérer ;
# - télécharger l’artefact dans `model/imported_model/` ;
# - générer un `model_metadata.json` simple ;
# - vérifier que le modèle se recharge localement.

# %%
from src.config import PATHS
from scripts.import_model_mlflow import import_model

# %%
metadata = import_model()
print(PATHS.model_metadata.read_text(encoding="utf-8"))
# Out:
# ...
# Connexion MLflow configurée : OK
# Source de configuration MLflow : env
# Modèle importé dans : <PROJECT_ROOT>/model/imported_model
# Métadonnées écrites dans : <PROJECT_ROOT>/model/model_metadata.json
# Vérification de rechargement local : OK
# {
#   "imported_at_utc": "2026-03-20T16:29:23.924501+00:00",
#   "source": {
#     "tracking_uri": null,
#     "tracking_uri_source": "env"
#   },
#   "fallback": {
#     "source": {
#       "tracking_uri": null,
#       "tracking_uri_source": "hardcoded_metadata",
#       "model_uri": "mlflow-artifacts:/9/a7a30e9114c14acf9a3908650109c6bc/artifacts/model"
#     }
#   },
#   "local": {
#     "model_dir": "<PROJECT_ROOT>/model/imported_model",
#     "metadata_path": "<PROJECT_ROOT>/model/model_metadata.json"
#   }
# }
